# %%
import pandas as pd

b = pd.read_csv('winemag-data-130k-v2.csv')
b
# Out:
#         Unnamed: 0   country  \
# 0                0     Italy
# 1                1  Portugal
# 2                2        US
# 3                3        US
# 4                4        US
# ...            ...       ...
# 129966      129966   Germany
# 129967      129967        US
# 129968      129968    France
# 129969      129969    France
# 129970      129970    France
#
#                                               description  \
# 0       Aromas include tropical fruit, broom, brimston...
# 1       This is ripe and fruity, a wine that is smooth...
# 2       Tart and snappy, the flavors of lime flesh and...
# 3       Pineapple rind, lemon pith and orange blossom ...
# 4       Much like the regular bottling from 2012, this...
# ...                                                   ...
# 129966  Notes of honeysuckle and cantaloupe sweeten th...
# 129967  Citation is given as much as a decade of bottl...
# 129968  Well-drained gravel soil gives this wine its c...
# ...

# %%
b.head()
# Out:
#    Unnamed: 0   country                                        description  \
# 0           0     Italy  Aromas include tropical fruit, broom, brimston...
# 1           1  Portugal  This is ripe and fruity, a wine that is smooth...
# 2           2        US  Tart and snappy, the flavors of lime flesh and...
# 3           3        US  Pineapple rind, lemon pith and orange blossom ...
# 4           4        US  Much like the regular bottling from 2012, this...
#
#                           designation  points  price           province  \
# 0                        Vulkà Bianco      87    NaN  Sicily & Sardinia
# 1                            Avidagos      87   15.0              Douro
# 2                                 NaN      87   14.0             Oregon
# 3                Reserve Late Harvest      87   13.0           Michigan
# 4  Vintner's Reserve Wild Child Block      87   65.0             Oregon
#
#               region_1           region_2         taster_name  \
# ...

# %%
b.set_index('title')
# Out:
#                                                     Unnamed: 0   country  \
# title
# Nicosia 2013 Vulkà Bianco  (Etna)                            0     Italy
# Quinta dos Avidagos 2011 Avidagos Red (Douro)                1  Portugal
# Rainstorm 2013 Pinot Gris (Willamette Valley)                2        US
# St. Julian 2013 Reserve Late Harvest Riesling (...           3        US
# Sweet Cheeks 2012 Vintner's Reserve Wild Child ...           4        US
# ...                                                        ...       ...
# Dr. H. Thanisch (Erben Müller-Burggraef) 2013 B...      129966   Germany
# Citation 2004 Pinot Noir (Oregon)                       129967        US
# Domaine Gresser 2013 Kritt Gewurztraminer (Alsace)      129968    France
# Domaine Marcel Deiss 2012 Pinot Gris (Alsace)           129969    France
# Domaine Schoffit 2012 Lieu-dit Harth Cuvée Caro...      129970    France
#
# ...

# %%
c = pd.read_csv('winemag-data-130k-v2.csv', index_col=10)
c
# Out:
#                        Unnamed: 0   country  \
# taster_twitter_handle
# @kerinokeefe                    0     Italy
# @vossroger                      1  Portugal
# @paulgwine                      2        US
# NaN                             3        US
# @paulgwine                      4        US
# ...                           ...       ...
# NaN                        129966   Germany
# @paulgwine                 129967        US
# @vossroger                 129968    France
# @vossroger                 129969    France
# @vossroger                 129970    France
#
#                                                              description  \
# taster_twitter_handle
# @kerinokeefe           Aromas include tropical fruit, broom, brimston...
# @vossroger             This is ripe and fruity, a wine that is smooth...
# @paulgwine             Tart and snappy, the flavors of lime flesh and...
# NaN                    Pineapple rind, lemon pith and orange blossom ...
# ...

# %%
b.loc[b.country == 'Italy']
# Out:
#        country                                        description  \
# 0        Italy  Aromas include tropical fruit, broom, brimston...
# 6        Italy  Here's a bright, informal red that opens with ...
# 13       Italy  This is dominated by oak and oak-driven aromas...
# 22       Italy  Delicate aromas recall white flower and citrus...
# 24       Italy  Aromas of prune, blackcurrant, toast and oak c...
# ...        ...                                                ...
# 129929   Italy  This luminous sparkler has a sweet, fruit-forw...
# 129943   Italy  A blend of Nero d'Avola and Syrah, this convey...
# 129947   Italy  A blend of 65% Cabernet Sauvignon, 30% Merlot ...
# 129961   Italy  Intense aromas of wild cherry, baking spice, t...
# 129962   Italy  Blackberry, cassis, grilled herb and toasted a...
#
#                       designation  points  price           province  \
# 0                    Vulkà Bianco      87    NaN  Sicily & Sardinia
# ...

# %%
b.loc[(b.country=='Italy') & (b.points>=90)]
# Out:
#         Unnamed: 0 country                                        description  \
# 120            120   Italy  Slightly backward, particularly given the vint...
# 130            130   Italy  At the first it was quite muted and subdued, b...
# 133            133   Italy  Einaudi's wines have been improving lately, an...
# 135            135   Italy  The color is just beginning to show signs of b...
# 140            140   Italy  A big, fat, luscious wine with plenty of toast...
# ...            ...     ...                                                ...
# 129929      129929   Italy  This luminous sparkler has a sweet, fruit-forw...
# 129943      129943   Italy  A blend of Nero d'Avola and Syrah, this convey...
# 129947      129947   Italy  A blend of 65% Cabernet Sauvignon, 30% Merlot ...
# 129961      129961   Italy  Intense aromas of wild cherry, baking spice, t...
# 129962      129962   Italy  Blackberry, cassis, grilled herb and toasted a...
#
# ...

# %%
b.loc[b.country.isin(['Italy','France'])]
# Out:
#         Unnamed: 0 country                                        description  \
# 0                0   Italy  Aromas include tropical fruit, broom, brimston...
# 6                6   Italy  Here's a bright, informal red that opens with ...
# 7                7  France  This dry and restrained wine offers spice in p...
# 9                9  France  This has great depth of flavor with its fresh ...
# 11              11  France  This is a dry wine, very spicy, with a tight, ...
# ...            ...     ...                                                ...
# 129964      129964  France  Initially quite muted, this wine slowly develo...
# 129965      129965  France  While it's rich, this beautiful dry wine also ...
# 129968      129968  France  Well-drained gravel soil gives this wine its c...
# 129969      129969  France  A dry style of Pinot Gris, this is crisp with ...
# 129970      129970  France  Big, rich and off-dry, this is powered by inte...
#
# ...

# %%
b.loc[b.price.notnull()]
# Out:
#         Unnamed: 0   country  \
# 1                1  Portugal
# 2                2        US
# 3                3        US
# 4                4        US
# 5                5     Spain
# ...            ...       ...
# 129966      129966   Germany
# 129967      129967        US
# 129968      129968    France
# 129969      129969    France
# 129970      129970    France
#
#                                               description  \
# 1       This is ripe and fruity, a wine that is smooth...
# 2       Tart and snappy, the flavors of lime flesh and...
# 3       Pineapple rind, lemon pith and orange blossom ...
# 4       Much like the regular bottling from 2012, this...
# 5       Blackberry and raspberry aromas show a typical...
# ...                                                   ...
# 129966  Notes of honeysuckle and cantaloupe sweeten th...
# 129967  Citation is given as much as a decade of bottl...
# 129968  Well-drained gravel soil gives this wine its c...
# ...

# %%
b.loc[b.region_2.isnull()]
# Out:
#         Unnamed: 0   country  \
# 0                0     Italy
# 1                1  Portugal
# 3                3        US
# 5                5     Spain
# 6                6     Italy
# ...            ...       ...
# 129965      129965    France
# 129966      129966   Germany
# 129968      129968    France
# 129969      129969    France
# 129970      129970    France
#
#                                               description  \
# 0       Aromas include tropical fruit, broom, brimston...
# 1       This is ripe and fruity, a wine that is smooth...
# 3       Pineapple rind, lemon pith and orange blossom ...
# 5       Blackberry and raspberry aromas show a typical...
# 6       Here's a bright, informal red that opens with ...
# ...                                                   ...
# 129965  While it's rich, this beautiful dry wine also ...
# 129966  Notes of honeysuckle and cantaloupe sweeten th...
# 129968  Well-drained gravel soil gives this wine its c...
# ...

# %%
d=b.points.mean()
d
# Out:
# 88.44713820775404

# %%
b.points.map(lambda x:x-d)
# Out:
# 0        -1.447138
# 1        -1.447138
# 2        -1.447138
# 3        -1.447138
# 4        -1.447138
#             ...
# 129966    1.552862
# 129967    1.552862
# 129968    1.552862
# 129969    1.552862
# 129970    1.552862
# Name: points, Length: 129971, dtype: float64

# %%
def K(b):
    b.points=b.points-d
    return b

b
# Out:
#         Unnamed: 0   country  \
# 0                0     Italy
# 1                1  Portugal
# 2                2        US
# 3                3        US
# 4                4        US
# ...            ...       ...
# 129966      129966   Germany
# 129967      129967        US
# 129968      129968    France
# 129969      129969    France
# 129970      129970    France
#
#                                               description  \
# 0       Aromas include tropical fruit, broom, brimston...
# 1       This is ripe and fruity, a wine that is smooth...
# 2       Tart and snappy, the flavors of lime flesh and...
# 3       Pineapple rind, lemon pith and orange blossom ...
# 4       Much like the regular bottling from 2012, this...
# ...                                                   ...
# 129966  Notes of honeysuckle and cantaloupe sweeten th...
# 129967  Citation is given as much as a decade of bottl...
# 129968  Well-drained gravel soil gives this wine its c...
# ...

# %%
b.groupby('points').points.count()
# Out:
# points
# 80       397
# 81       692
# 82      1836
# 83      3025
# 84      6480
# 85      9530
# 86     12600
# 87     16933
# 88     17207
# 89     12226
# 90     15410
# 91     11359
# 92      9613
# 93      6489
# 94      3758
# 95      1535
# 96       523
# 97       229
# 98        77
# 99        33
# 100       19
# Name: points, dtype: int64

# %%
b.groupby(['country']).price.agg([len,min,max])
# Out:
#                           len   min     max
# country
# Argentina                3800   4.0   230.0
# Armenia                     2  14.0    15.0
# Australia                2329   5.0   850.0
# Austria                  3345   7.0  1100.0
# Bosnia and Herzegovina      2  12.0    13.0
# Brazil                     52  10.0    60.0
# Bulgaria                  141   8.0   100.0
# Canada                    257  12.0   120.0
# Chile                    4472   5.0   400.0
# China                       1  18.0    18.0
# Croatia                    73  12.0    65.0
# Cyprus                     11  11.0    21.0
# Czech Republic             12  15.0    45.0
# Egypt                       1   NaN     NaN
# England                    74  25.0    95.0
# France                  22093   5.0  3300.0
# Georgia                    86   9.0    40.0
# Germany                  2165   5.0   775.0
# Greece                    466   8.0    79.0
# Hungary                   146  10.0   764.0
# ...

# %%
a = pd.read_csv('winemag-data-130k-v2.csv')
b=a.groupby(['country','province']).description.agg([len])
c=b.index
type(c)
# Out:
# pandas.core.indexes.multi.MultiIndex

# %%
a = pd.read_csv('winemag-data-130k-v2.csv')
b=a.groupby(['country','province']).description.agg([len])
c=b.reset_index()
c.sort_values(by='len',ascending=False)
# Out:
#           country         province    len
# 392            US       California  36247
# 415            US       Washington   8639
# 118        France         Bordeaux   5941
# 227         Italy          Tuscany   5897
# 409            US           Oregon   5373
# ..            ...              ...    ...
# 101       Croatia              Krk      1
# 247   New Zealand        Gladstone      1
# 357  South Africa  Piekenierskloof      1
# 63          Chile          Coelemu      1
# 149        Greece           Beotia      1
#
# [425 rows x 3 columns]

# %%
c.sort_values(by=['country','len'])
# Out:
#        country          province   len
# 1    Argentina             Other   536
# 0    Argentina  Mendoza Province  3264
# 2      Armenia           Armenia     2
# 6    Australia          Tasmania    42
# 4    Australia   New South Wales    85
# ..         ...               ...   ...
# 421    Uruguay        Montevideo    11
# 422    Uruguay          Progreso    11
# 420    Uruguay           Juanico    12
# 424    Uruguay           Uruguay    24
# 419    Uruguay         Canelones    43
#
# [425 rows x 3 columns]

# %%
a = pd.read_csv('winemag-data-130k-v2.csv')
a[pd.isnull(a.country)]
# Out:
#         Unnamed: 0 country                                        description  \
# 913            913     NaN  Amber in color, this wine has aromas of peach ...
# 3131          3131     NaN  Soft, fruity and juicy, this is a pleasant, si...
# 4243          4243     NaN  Violet-red in color, this semisweet wine has a...
# 9509          9509     NaN  This mouthwatering blend starts with a nose of...
# 9750          9750     NaN  This orange-style wine has a cloudy yellow-gol...
# ...            ...     ...                                                ...
# 124176      124176     NaN  This Swiss red blend is composed of four varie...
# 129407      129407     NaN  Dry spicy aromas of dusty plum and tomato add ...
# 129408      129408     NaN  El Capricho is one of Uruguay's more consisten...
# 129590      129590     NaN  A blend of 60% Syrah, 30% Cabernet Sauvignon a...
# 129900      129900     NaN  This wine offers a delightful bouquet of black...
#
# ...

# %%
a.region_2.fillna('unknown')
# Out:
# 0                   unknown
# 1                   unknown
# 2         Willamette Valley
# 3                   unknown
# 4         Willamette Valley
#                 ...
# 129966              unknown
# 129967         Oregon Other
# 129968              unknown
# 129969              unknown
# 129970              unknown
# Name: region_2, Length: 129971, dtype: object

# %%
a = pd.read_csv('winemag-data-130k-v2.csv')
a.rename(columns={'points':'score'})
# Out:
#         Unnamed: 0   country  \
# 0                0     Italy
# 1                1  Portugal
# 2                2        US
# 3                3        US
# 4                4        US
# ...            ...       ...
# 129966      129966   Germany
# 129967      129967        US
# 129968      129968    France
# 129969      129969    France
# 129970      129970    France
#
#                                               description  \
# 0       Aromas include tropical fruit, broom, brimston...
# 1       This is ripe and fruity, a wine that is smooth...
# 2       Tart and snappy, the flavors of lime flesh and...
# 3       Pineapple rind, lemon pith and orange blossom ...
# 4       Much like the regular bottling from 2012, this...
# ...                                                   ...
# 129966  Notes of honeysuckle and cantaloupe sweeten th...
# 129967  Citation is given as much as a decade of bottl...
# 129968  Well-drained gravel soil gives this wine its c...
# ...

# %%
a.rename_axis('wines',axis="index").rename_axis('fields',axis="columns")
# Out:
# fields  Unnamed: 0   country  \
# wines
# 0                0     Italy
# 1                1  Portugal
# 2                2        US
# 3                3        US
# 4                4        US
# ...            ...       ...
# 129966      129966   Germany
# 129967      129967        US
# 129968      129968    France
# 129969      129969    France
# 129970      129970    France
#
# fields                                        description  \
# wines
# 0       Aromas include tropical fruit, broom, brimston...
# 1       This is ripe and fruity, a wine that is smooth...
# 2       Tart and snappy, the flavors of lime flesh and...
# 3       Pineapple rind, lemon pith and orange blossom ...
# 4       Much like the regular bottling from 2012, this...
# ...                                                   ...
# 129966  Notes of honeysuckle and cantaloupe sweeten th...
# 129967  Citation is given as much as a decade of bottl...
# 129968  Well-drained gravel soil gives this wine its c...
# ...

# %%
###ritha
